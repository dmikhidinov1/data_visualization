# %% [markdown]
# ## Week 5-6 Assignment
#
# Student: Dilyor Mikhidinov
# Dataset:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('archive/Pokemon.csv')
df.head()
# Out:
#    Number           Name Type 1  Type 2                    Abilities  HP  Att  \
# 0       1      Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 1       2        Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 2       3       Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3       3  Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4       4     Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
#
#    Def  Spa  Spd  ...  Against Ground  Against Flying  Against Psychic  \
# 0   49   65   65  ...           $1.00           $2.00            $2.00
# 1   63   80   80  ...           $1.00           $2.00            $2.00
# 2   83  100  100  ...           $1.00           $2.00            $2.00
# 3  123  122  120  ...           $1.00           $2.00            $2.00
# 4   43   60   50  ...           $2.00           $1.00            $1.00
#
# ...

# %% [markdown]
# ## Analysis of Pokemon Type strength

# %%
pd.options.display.float_format = '${:,.2f}'.format
#creating a dataframe grouped by Type1 and averaged by the mean of HP

a = df.groupby("Type 1")
mean_df = a.mean()
mean_df = mean_df.reset_index()

# %% [markdown]
# HP

# %%
#now lets create bar chart
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['HP'], width=0.5) #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Average HP')
ax.set_title('Average HP of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# I created the same bar chart for other STATS (attack, defence, speed, etc.) of the pokemons in the dataset. Please count these all one type of visualization. I will create other types after this, I just considered it would be better story telling to view all the Pokemon stats

# %% [markdown]
# Attack

# %%
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['Att'], width=0.5, color='#FF7F7F') #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Average Attack')
ax.set_title('Average Attack of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# Defense

# %%
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['Def'], width=0.5, color='orange') #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Average Defense')
ax.set_title('Average Defense of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# Speical Attack

# %%
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['Spa'], width=0.5, color='pink') #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Average Special Attack')
ax.set_title('Average Special Attack of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# Special Defense

# %%
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['Spd'], width=0.5, color='grey') #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Average Special Defense')
ax.set_title('Average Special Defense of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# Speed

# %%
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['Spe'], width=0.5, color='#90EE90') #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Average Speed')
ax.set_title('Average Speed of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# Higher each stat shows how strong is the given Pokemon. The last stat related bar chart illustrates Average total of stats based on Pokemon Primary Type.

# %%
fig, ax = plt.subplots(figsize=(15,4)) #assigning the figure size
bars = ax.bar(mean_df['Type 1'], mean_df['BST'], width=0.5, color='black') #assigning x and y axis of chart from the mean_df dataframe
#setting names of labes and chart title
ax.set_xlabel('Pokemon Type')
ax.set_ylabel('Overall Strength (Average of Sum of Base Stats)')
ax.set_title('Overall Strength of Pokemons from each Primary Type')
#the following is the code that allowed me to print the labels for each bar
for bar in bars:
    height = bar.get_height()
    label_x_pos = bar.get_x() + bar.get_width() / 2
    ax.text(label_x_pos, round(height,2), s=f'{round(height,2)}', ha='center', va='bottom')
    # above I am also using round function to to show short version of values instead of scientific notation values

# %% [markdown]
# As we can see from the above bar chart Dragon, Psychic and Steel Pokemons are the strongest in average. Having highest sum of base stats

# %% [markdown]
# ## Top 10 strongest Dragon Type Pokemons

# %%
dragon_df = df[df["Type 1"] == "Dragon"]
dragon_df = dragon_df.nlargest(10, ['BST'])

# %%
plt.rcdefaults()
fig, ax = plt.subplots(figsize=(8,4))
bars = ax.barh(dragon_df["Name"], dragon_df["BST"], align='center')
ax.set_xlabel('Total of Base Stats')
ax.set_title('Top 10 the strongest Dragon type Pokemons')
for index, value in enumerate(dragon_df["BST"]):
    plt.text(value, index, str(value))

# %%
#correlation between stats
import seaborn as sns
pokemon_stats = df[(df['Final Evolution']==1)&(df['Legendary']==0)&(df['Mega Evolution']==0)][['HP', 'Att', 'Def', 'Spa', 'Spd', 'Spe']]
g = sns.PairGrid(pokemon_stats)
g.map(sns.regplot,scatter_kws = {'alpha': 0.5,'s':3})
plt.show()
plt.close()

# %%
dragon_catch = df.loc[df['Type 1'] == "Dragon"]
psychic_catch = df.loc[df['Type 1'] == "Psychic"]
#df[df["Type 1"] == "Psychic"]["Catch Rate"]
steel_catch = df.loc[df['Type 1'] == "Steel"]

fig, ax = plt.subplots(figsize=(15,9))
ax.scatter(dragon_catch["BST"], dragon_catch["Catch Rate"], alpha=.5)
ax.scatter(psychic_catch["BST"], psychic_catch["Catch Rate"], alpha=.5)
ax.scatter(steel_catch["BST"], steel_catch["Catch Rate"], alpha=.5)
ax.set_title('Scatter plot Base stats&Catch Rate', fontsize = 16)
ax.set_xlabel('Base Stats')
ax.set_ylabel('Catch Rate')
# Out:
# Text(0, 0.5, 'Catch Rate')

# %% [markdown]
# Next I am looking and 3 strongest Pokemon Types Dragon, Psychic and Steel and their Attack/Defense scatter plot

# %%
plt.figure(figsize=(12, 8))

plt.scatter(dragon_catch["Att"], dragon_catch["Def"], c='green', label='Dragon')
plt.scatter(psychic_catch["Att"], psychic_catch["Def"], c='#FF7F7F', label='Psychic')
plt.scatter(steel_catch["Att"], steel_catch["Def"], c='blue', label='Steel')
plt.legend()
plt.title('Scatter plot Attack & Defense for Dragon, Psychic and Steel Pokemons')
plt.xlabel('Attack Stat')
plt.ylabel('Defense')
plt.show()

# %% [markdown]
# Another interesting analysis I wanted to do was to see what is the catch rate of Pokemon Types that reached the final evolution

# %%
final_evolution = df.loc[(df['Final Evolution'] == 1)]

plt.figure(figsize=(15,8), dpi = 80)
sns.boxplot(x = "Type 1", y = "Catch Rate", data=final_evolution, notch=False)

# I found this function online for finding numbers of observations 
def add_n_obs(df,group_col,y):
    medians_dict = {grp[0]:grp[1][y].median() for grp in df.groupby(group_col)}
    xticklabels = [x.get_text() for x in plt.gca().get_xticklabels()]
    n_obs = df.groupby(group_col)[y].size().values
    for (x, xticklabel), n_ob in zip(enumerate(xticklabels), n_obs):
        plt.text(x, medians_dict[xticklabel]*-0.1, ""+str(n_ob), horizontalalignment='center', fontdict={'size':8}, color='black')

add_n_obs(df,group_col='Type 1',y='Catch Rate')    
plt.title('Catch Rate of Pokemon Types that reached Final Evolution', fontsize=22)
plt.show()

# %%
plt.figure(figsize=(13,10), dpi= 80)
group_col = 'Legendary'
order_of_bars = df['Type 1'].unique()[::-1]
colors = [plt.cm.Spectral(i/float(len(df[group_col].unique())-1)) for i in range(len(df[group_col].unique()))]

for c, group in zip(colors, df[group_col].unique()):
    sns.barplot(x='BST', y='Type 1', data=df.loc[df[group_col]==group, :], order=order_of_bars, color=c, label=group)

# Decorations    
plt.xlabel("$BST$")
plt.ylabel("Type 1")
plt.yticks(fontsize=12)
plt.title("", fontsize=22)
plt.legend()
plt.show()
